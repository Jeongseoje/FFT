# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft, ifft

# Generate a sample time series data
t = np.linspace(0, 1, 400, endpoint=False)
# signal = np.sin(2 * np.pi * 5 * t) + np.sin(2 * np.pi * 10 * t)  # A sum of two sine waves
signal = np.sin(1 * np.pi * 25 * t) # A one sine waves

# Apply Fourier transform

freq_domain3 = fft(signal, n=1000);

freq_domain4 = fft(signal, n=10000);

# %%
# Compute the frequency bins
N = len(t)
T = t[1] - t[0]  # sample spacing
f = np.linspace(0.0, 1.0/(2.0*T), N//2)

# Compute the magnitude of the Fourier coefficients
magnitude = 2.0/N * np.abs(freq_domain3[:N//2])

# Plot the spectrum
plt.figure(figsize=(6, 4))
plt.plot(f, magnitude)
plt.title('Frequency Spectrum of the Signal')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.grid(True)
plt.show()

# %%
# Compute the frequency bins
N = len(t)
T = t[1] - t[0]  # sample spacing
f = np.linspace(0.0, 1.0/(2.0*T), N//2)

# Compute the magnitude of the Fourier coefficients
magnitude = 2.0/N * np.abs(freq_domain4[:N//2])

# Plot the spectrum
plt.figure(figsize=(6, 4))
plt.plot(f, magnitude)
plt.title('Frequency Spectrum of the Signal')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.grid(True)
plt.show()
